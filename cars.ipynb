# %%
pip install matplotlib.pyplot

# %%
pip install seaborn

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#import streamlit as st

# %%
cars=pd.read_csv(r"C:\Users\GASTO\Downloads\car_prices (1).csv")
cars
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer   color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0   white
# ...

# %%
cars.head(10)
# Out:
#    year       make                model                       trim  \
# 0  2015        Kia              Sorento                         LX
# 1  2015        Kia              Sorento                         LX
# 2  2014        BMW             3 Series                 328i SULEV
# 3  2015      Volvo                  S60                         T5
# 4  2014        BMW  6 Series Gran Coupe                       650i
# 5  2015     Nissan               Altima                      2.5 S
# 6  2014        BMW                   M5                       Base
# 7  2014  Chevrolet                Cruze                        1LT
# 8  2014       Audi                   A4  2.0T Premium Plus quattro
# 9  2014  Chevrolet               Camaro                         LT
#
#           body transmission                vin state  condition  odometer  \
# 0          SUV    automatic  5xyktca69fg566472    ca        5.0   16639.0
# 1          SUV    automatic  5xyktca69fg561319    ca        5.0    9393.0
# ...

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 558837 entries, 0 to 558836
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          558837 non-null  int64
#  1   make          548536 non-null  object
#  2   model         548438 non-null  object
#  3   trim          548186 non-null  object
#  4   body          545642 non-null  object
#  5   transmission  493485 non-null  object
#  6   vin           558833 non-null  object
#  7   state         558837 non-null  object
#  8   condition     547017 non-null  float64
#  9   odometer      558743 non-null  float64
#  10  color         558088 non-null  object
#  11  interior      558088 non-null  object
#  12  seller        558837 non-null  object
#  13  mmr           558799 non-null  float64
#  14  sellingprice  558825 non-null  float64
#  15  saledate      558825 non-null  object
# dtypes: float64(4), int64(1), object(11)
# memory usage: 68.2+ MB

# %%
cars.shape
# Out:
# (558837, 16)

# %%
cars.columns
# Out:
# Index(['year', 'make', 'model', 'trim', 'body', 'transmission', 'vin', 'state',
#        'condition', 'odometer', 'color', 'interior', 'seller', 'mmr',
#        'sellingprice', 'saledate'],
#       dtype='object')

# %%
cars.drop(columns=["transmission", "state"],inplace=True)

# %%
cars
# Out:
#         year    make                model         trim       body  \
# 0       2015     Kia              Sorento           LX        SUV
# 1       2015     Kia              Sorento           LX        SUV
# 2       2014     BMW             3 Series   328i SULEV      Sedan
# 3       2015   Volvo                  S60           T5      Sedan
# 4       2014     BMW  6 Series Gran Coupe         650i      Sedan
# ...      ...     ...                  ...          ...        ...
# 558832  2015     Kia                 K900       Luxury      Sedan
# 558833  2012     Ram                 2500  Power Wagon   Crew Cab
# 558834  2012     BMW                   X5    xDrive35d        SUV
# 558835  2015  Nissan               Altima        2.5 S      sedan
# 558836  2014    Ford                F-150          XLT  SuperCrew
#
#        transmission                vin state  condition  odometer   color  \
# 0         automatic  5xyktca69fg566472    ca        5.0   16639.0   white
# ...

# %%
cars.isna().sum()
# Out:
# year                0
# make            10301
# model           10399
# trim            10651
# body            13195
# vin                 4
# condition       11820
# odometer           94
# color             749
# interior          749
# seller              0
# mmr                38
# sellingprice       12
# saledate           12
# dtype: int64

# %%
cars.dropna(inplace=True)# it makes sure you drop the missing value from the data and inplace it updates  the real data  hence no null values

# %%
cars.isna().sum()
# Out:
# year            0
# make            0
# model           0
# trim            0
# body            0
# vin             0
# condition       0
# odometer        0
# color           0
# interior        0
# seller          0
# mmr             0
# sellingprice    0
# saledate        0
# dtype: int64

# %%
cars.duplicated().sum()
# Out:
# np.int64(0)

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 533648 entries, 0 to 558836
# Data columns (total 14 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   year          533648 non-null  int64
#  1   make          533648 non-null  object
#  2   model         533648 non-null  object
#  3   trim          533648 non-null  object
#  4   body          533648 non-null  object
#  5   vin           533648 non-null  object
#  6   condition     533648 non-null  float64
#  7   odometer      533648 non-null  float64
#  8   color         533648 non-null  object
#  9   interior      533648 non-null  object
#  10  seller        533648 non-null  object
#  11  mmr           533648 non-null  float64
#  12  sellingprice  533648 non-null  float64
#  13  saledate      533648 non-null  object
# dtypes: float64(4), int64(1), object(9)
# memory usage: 61.1+ MB

# %%
cars.shape
# Out:
# (533648, 14)

# %%
cars['make'].value_counts().head()
# Out:
# make
# Ford         91907
# Chevrolet    58817
# Nissan       53085
# Toyota       38991
# Dodge        30100
# Name: count, dtype: int64

# %%
cars['make'].value_counts().tail()
# Out:
# make
# Rolls-Royce    16
# Fisker          9
# Lamborghini     4
# Daewoo          2
# Lotus           1
# Name: count, dtype: int64

# %%
cars['seller'].value_counts()
# Out:
# seller
# nissan-infiniti lt                    19677
# ford motor credit company llc         19082
# the hertz corporation                 18248
# santander consumer                    14965
# avis corporation                      12503
#                                       ...
# heartland area fcu                        1
# santander consumer/renig                  1
# cool green preowned auto sales llc        1
# century auto sales                        1
# i -5 uhlmann rv                           1
# Name: count, Length: 12735, dtype: int64

# %%
cars.groupby('make')['sellingprice'].mean().sort_values(ascending=False)
# Out:
# make
# Rolls-Royce      153456.250000
# Ferrari          127210.526316
# Lamborghini      112625.000000
# Bentley           74349.130435
# Tesla             67054.347826
# Aston Martin      54812.000000
# Fisker            46461.111111
# Maserati          45632.442748
# Lotus             40800.000000
# Porsche           40348.898604
# Land Rover        33302.125293
# Ram               25323.258746
# Mercedes-Benz     21650.054477
# BMW               21380.865343
# Infiniti          20518.970200
# Lexus             20430.600257
# Jaguar            20245.588962
# Audi              20173.588287
# GMC               17140.483668
# Lincoln           17032.951346
# Subaru            15558.192705
# Cadillac          15474.520138
# HUMMER            15364.615776
# Jeep              15174.187504
# Ford              14662.538816
# Acura             14227.218445
# MINI              12393.053363
# Toyota            12362.094073
# Chevrolet         12096.690991
# Kia               11876.584565
# ...

# %%
cars.sort_values(by='sellingprice',ascending=False)
# Out:
#         year           make         model      trim          body  \
# 344905  2014           Ford        Escape  Titanium           SUV
# 548169  2011        Ferrari    458 Italia      Base         coupe
# 446949  2015  Mercedes-Benz       S-Class   S65 AMG         Sedan
# 545523  2013    Rolls-Royce         Ghost      Base         sedan
# 125095  2012    Rolls-Royce         Ghost      Base         Sedan
# ...      ...            ...           ...       ...           ...
# 449497  2003      Chevrolet        Impala      Base         Sedan
# 423599  1995            BMW      3 Series      325i         Sedan
# 48453   2003  Mercedes-Benz       E-Class      E500         Sedan
# 348252  1995          Isuzu         Rodeo        LS           SUV
# 293223  2014           Ford  E-Series Van     E-250  E-Series Van
#
#                       vin  condition  odometer  color interior  \
# 344905  1fmcu9j98eua23833       43.0   27802.0  green      tan
# ...

# %%
numeric_col=cars.select_dtypes(include=('int64','Float64'))

# %%
correlation_matrix=numeric_col.corr()

# %%
sns.heatmap(correlation_matrix,annot=True , cmap="coolwarm", linewidths=0.5)# annot helps the heatmap to represent different correlations in numeric_values
plt.title("Correlation Heatmap")#linewidths a parameter to set the width of the line that divide the cell in heatmap
plt.show()

# %%
cars['year'].plot.hist(bins=20)
plt.title('distribution of cars years')
plt.show()

# %%
plt.scatter(cars['odometer'],cars['sellingprice'],alpha=0.5)
plt.xlabel('odometer')
plt.ylabel('sellingprice')
plt.title('scatter plot of odometer-sellingprice')# the higher the odometer (distance covered same as millege)the  lesser the car value while the lower the odometer the higher the selling price
plt.show()

# %%
mean_price_by_model = cars.groupby("model")["sellingprice"].median().sort_values(ascending=False)
mean_price_by_model
# Out:
# model
# 458 Italia             183000.0
# i8                     159000.0
# SLS AMG GT             156500.0
# Flying Spur            154000.0
# Ghost                  149400.0
#                          ...
# Spirit                    300.0
# Tracer                    300.0
# Windstar Cargo            262.5
# Eighty-Eight Royale       250.0
# Paseo                     150.0
# Name: sellingprice, Length: 772, dtype: float64

# %%
mean_price_by_model=cars.groupby('make')['sellingprice'].median().sort_values(ascending=False).head(10)
mean_price_by_model.plot(kind='bar')
plt.xlabel('carsmake')          
plt.ylabel('sellingprice')
plt.title('avgselling price by make')
plt.show()

# %%
mean_price_by_model=cars.groupby('make')['sellingprice'].mean().sort_values(ascending=False).head(10)
mean_price_by_model.plot(kind="bar")
plt.xlabel('carmake')
plt.ylabel('avgsellingprice')
plt.title('avgselling price by make')
plt.show()

# %%
x = data["model"]
y = data["make"]
y1 = data["sellingprice"]

# plt.figure(figsize=(12,5))

fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(12, 5))

ax[0].plot(x, y, label="model", color="make")
ax[1].plot(x, y1, label="sellingprice", color="maroon")

ax[0].set_title("model Share Prices")
ax[1].set_title("sellingprice Share Prices")
ax[0].set_ylabel("Share Price(model)")
ax[1].set_ylabel("Share Price(make)")
ax[0].set_xlabel("Date/Time(Cotton)")
ax[1].set_xlabel("Date/Time(WTI)")
plt.legend(ncols=2)
# ax[0].set_ylim(0,140)
plt.show()

# %%
sns.boxplot(x='sellingprice',data=cars)
plt.title('Box plot of car prices')
plt.show()# need to remove the pliers in our data

# %%
top_10_models=cars['model'].value_counts().head(10)
top_10_models.plot(kind='bar')
plt.xlabel('carsmodels')
plt.ylabel('frequency')
plt.title('Top 10 Most Common Car Model')
plt.show()

# %%
plt.scatter(cars['mmr'],cars['sellingprice'],alpha=0.5)# mmr- is an industry tool used to estimate the wholwprice of a used car
plt.xlabel('carssmmr')# sellingprice is the actual sale price of the vehicle
plt.ylabel('sellingprice')
plt.title('scatterplot of mmr_sellingprice')
plt.show()

# %%
cars[cars['odometer']< 20000]['odometer'].plot.hist(bins=20)
plt.title('distribution of low_odometer cars')
plt.show()

# %%
cars_year=cars['year'].value_counts().sort_values(ascending=False).head(10)
cars_year.plot(kind='bar')
plt.xlabel('year')
plt.ylabel('number of cars')
plt.title('cars count by year')
plt.show()

# %%
counts_color=cars.groupby('color')['model'].value_counts()
counts_color.sort_values(ascending=False)
# Out:
# color      model
# white      F-150          4438
# black      Altima         4190
# white      Altima         4001
# gray       Altima         2954
# silver     Altima         2528
#                           ...
# off-white  GranTurismo       1
#            GX 470            1
#            GLK-Class         1
#            GL-Class          1
# —          xA                1
# Name: count, Length: 7389, dtype: int64

# %%
cars_price=(
    cars.groupby(["model","sellingprice","color"]).size().reset_index(name="count")
    )
sorted_cars=cars_price.sort_values(by="count",ascending=False)
sorted_cars.head(10)
# Out:
#         model  sellingprice  color  count
# 22660  Altima       12000.0  white    125
# 22955  Altima       14000.0  white    114
# 22651  Altima       12000.0  black    113
# 22815  Altima       13000.0  white    113
# 22630  Altima       11800.0  white    111
# 22805  Altima       13000.0  black    103
# 22676  Altima       12200.0  black     95
# 22832  Altima       13200.0  black     93
# 22597  Altima       11600.0  white     92
# 22621  Altima       11800.0  black     91

# %%
sales_cars=cars.groupby(['seller','model'])['sellingprice'].mean()
sales_cars
# Out:
# seller                    model
# 1 cochran of monroeville  1500                23200.0
#                           300                  7800.0
#                           4Runner              1875.0
#                           5 Series             1400.0
#                           9-2X                 5100.0
#                                                ...
# zmax moto leasing inc     S60                  4200.0
# zoom auto                 Elantra              8000.0
# zuma autoboat             F-350 Super Duty    10000.0
# zumbrota ford sales llc   F-150               13800.0
# zygi auto corp            ES 350               7750.0
# Name: sellingprice, Length: 142747, dtype: float64

# %%
car_count_per_year=cars.groupby('year')['make'].count()
car_count_per_year.sort_values(ascending=False)# increase in technology its easier to create cars
# Out:
# year
# 2012    100610
# 2013     97571
# 2014     79885
# 2011     47557
# 2008     29964
# 2007     28020
# 2010     25384
# 2006     23836
# 2009     19892
# 2005     18841
# 2004     15265
# 2003     11737
# 2015      9120
# 2002      8770
# 2001      5868
# 2000      3917
# 1999      2623
# 1998      1673
# 1997      1200
# 1996       656
# 1995       572
# 1994       324
# 1993       155
# 1992       111
# 1991        57
# 1990        40
# Name: make, dtype: int64

# %%
min_price=cars.groupby(['year','color'])['sellingprice'].mean()
min_price.sort_values(ascending=False)
# Out:
# year  color
# 2015  off-white    32145.000000
#       —            29906.390977
#       black        29567.877138
# 2012  pink         29250.000000
# 2015  beige        28876.237624
#                        ...
# 2002  pink           300.000000
# 1992  beige          293.750000
# 1991  gray           275.000000
# 1993  purple         262.500000
# 1992  burgundy       200.000000
# Name: sellingprice, Length: 449, dtype: float64
